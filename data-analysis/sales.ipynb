# %% [markdown]
# <h3>DATA READING <h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
file_path = r"C:\\Users\\mayan\\Downloads\\DiwaliSalesData.csv"
try:
    sales = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    sales = pd.read_csv(file_path, encoding='ISO-8859-1')

# %% [markdown]
# <h1>DATA CLEANING</h1>

# %%
sales.head
# Out:
# <bound method NDFrame.head of        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
sales.shape
# Out:
# (11251, 15)

# %%
sales.isnull()
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
sales.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
(sales.notnull().sum()) - (sales.isnull().sum())
# Out:
# User_ID             11251
# Cust_name           11251
# Product_ID          11251
# Gender              11251
# Age Group           11251
# Age                 11251
# Marital_Status      11251
# State               11251
# Zone                11251
# Occupation          11251
# Product_Category    11251
# Orders              11251
# Amount              11227
# Status             -11251
# unnamed1           -11251
# dtype: int64

# %%
(sales.isnull().sum()/(sales.shape[0]*sales.shape[1]))
# Out:
# User_ID             0.000000
# Cust_name           0.000000
# Product_ID          0.000000
# Gender              0.000000
# Age Group           0.000000
# Age                 0.000000
# Marital_Status      0.000000
# State               0.000000
# Zone                0.000000
# Occupation          0.000000
# Product_Category    0.000000
# Orders              0.000000
# Amount              0.000071
# Status              0.066667
# unnamed1            0.066667
# dtype: float64

# %%
sales.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
sales.drop(labels= 'Status' , axis = 1 , inplace= True)

# %%
sales.drop(labels= 'unnamed1' , axis = 1 , inplace= True)

# %%
sales.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
sales.rename(columns= {'Marital_Status' : 'Marital Status'} , inplace= True)

# %% [markdown]
# <h1> EXPONENTIAL ANALYSIS <h1>

# %%
sales["Cust_name"].head(30).unique()
# Out:
# array(['Sanskriti', 'Kartik', 'Bindu', 'Sudevi', 'Joni', 'Balk',
#        'Shivangi', 'Kushal', 'Ginny', 'Harshita', 'Kargatis', 'Elijah',
#        'Vasudev', 'Cano', 'Lauren', 'Amy', 'Mick', 'Praneet', 'Ellis',
#        'Hrisheekesh', 'Grant', 'Gilcrest', 'Skaria', 'Eric', 'Gibson',
#        'Mahima', 'Etezadi', 'James'], dtype=object)

# %%
product = sales["Product_Category"]
plt.figure(figsize=(25,8))
Product = sns.countplot(x =product)
Product.bar_label(Product.containers[0])
plt.show()

# %% [markdown]
# As the plot analysis shows that the main product that is the store is sales in the diwali --- is food , clothing % apparel and electronic & gadgets.

# %%
sales["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
plt.figure(figsize=(5,4))
plt.title("GENDER DISTRIBUTION")
genders= sns.countplot(data = sales, x = "Gender" )
genders.bar_label(genders.containers[0])
plt.show()

# %% [markdown]
# As if the analysis now comes to the conclusion that the ratio of female is preaty high as compared to the ratio of males.

# %%
sales["Age"].unique()
sales["Age"].describe()
# Out:
# count    11251.000000
# mean        35.421207
# std         12.754122
# min         12.000000
# 25%         27.000000
# 50%         33.000000
# 75%         43.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(8,4))
plt.title("outlier in age")
sns.boxplot(data = sales , x = "Age")
plt.show()

# %% [markdown]
# The age has higer outliers

# %%
np.median(sales["Age"])
# Out:
# 33.0

# %%
plt.figure(figsize=(25,8))
plt.title("AGE OF BUYERS")
age = sns.countplot(data = sales , x = "Age")
age.bar_label(age.containers[0])
plt.show()

# %% [markdown]
# The plot shows that the average or the maximum age of the buyers are in the range of 26 to 35 , which is most likely to be female

# %%
plt.figure(figsize=(30,10))
plt.title("AGE OF BUYERS ACCORDING TO GENDER")
age = sns.countplot(data = sales , x = "Age" , hue = 'Gender' )
age.bar_label(age.containers[0])
age.bar_label(age.containers[1])
plt.show()

# %%
sales.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
sales["Age Group"].isnull().count()
# Out:
# 11251

# %%
sales["Age Group"].unique()
# Out:
# array(['26-35', '0-17', '18-25', '55+', '46-50', '51-55', '36-45'],
#       dtype=object)

# %%
plt.figure(figsize=(4, 5))
plt.title("AGE GROUP TABLE")
age_group = sns.countplot(data = sales , x = "Age Group" , color = 'blue' , palette = 'hls')
age_group.bar_label(age_group.containers[0])
age_group.bar_label(age_group.containers[1])
age_group.bar_label(age_group.containers[2])
age_group.bar_label(age_group.containers[3])
age_group.bar_label(age_group.containers[4])
age_group.bar_label(age_group.containers[5])
age_group.bar_label(age_group.containers[6])
plt.show()
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_8688\3430157549.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   age_group = sns.countplot(data = sales , x = "Age Group" , color = 'blue' , palette = 'hls')

# %% [markdown]
# as the age graph also has the age group of 26-35. that means that this age group are buying the most offtn or buyes the most

# %%
plt.figure(figsize=(8,4))
g = sns.countplot(data = sales , x = "Age Group" ,hue = "Gender")
g.bar_label(g.containers[0])
g.bar_label(g.containers[1])
plt.show()

# %%
sales["Product_ID"].unique()
# Out:
# array(['P00125942', 'P00110942', 'P00118542', ..., 'P00307142',
#        'P00044742', 'P00296942'], dtype=object)

# %%
sales["Product_ID"].describe()
# Out:
# count         11251
# unique         2351
# top       P00265242
# freq             53
# Name: Product_ID, dtype: object

# %%
sales["State"].unique()
# Out:
# array(['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Madhya Pradesh',
#        'Jharkhand', 'Kerala', 'Haryana', 'Bihar', 'Rajasthan',
#        'Uttarakhand', 'Telangana', 'Punjab'], dtype=object)

# %%
plt.figure(figsize=(22,6))
st = sns.countplot(data = sales , x = "State" , color = "blue" , palette= 'hls')
plt.show()
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_8688\3954183821.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   st = sns.countplot(data = sales , x = "State" , color = "blue" , palette= 'hls')

# %%
plt.figure(figsize=(30,7))
plt.title("States in which products are available")
state = sns.countplot(data = sales , x = "State" , hue = "Zone")
state.bar_label(state.containers[0])
state.bar_label(state.containers[1])
state.bar_label(state.containers[2])
state.bar_label(state.containers[3])
state.bar_label(state.containers[4])
#state.bar_label(state.containers[5])
#tate.bar_label(state.containers[6])
plt.show()

# %%
maharashtra = sales.loc[(sales["State"] == "Maharashtra")].count()
AP = sales.loc[(sales["State"] == "Andhra\xa0Pradesh")].count()
UP = sales.loc[(sales["State"] == "Uttar Pradesh")].count()
karnataka = sales.loc[(sales["State"] == "Karnataka")].count()
gujarat = sales.loc[(sales["State"] == "Gujarat")].count()
himachal_Pradesh = sales.loc[(sales["State"] == "Himachal Pradesh")].count()
delhi = sales.loc[(sales["State"] == "Delhi")].count()
MP = sales.loc[(sales["State"] == "Madhya Pradesh")].count()
jharkhand = sales.loc[(sales["State"] == "Jharkhand")].count()
kerala = sales.loc[(sales["State"] == "Kerala")].count()
haryana = sales.loc[(sales["State"] == "Haryana")].count()
bihar= sales.loc[(sales["State"] == "Bihar")].count()
rajasthan = sales.loc[(sales["State"] == "Rajasthan")].count()
uttarakhand = sales.loc[(sales["State"] == "Uttarakhand")].count()
telangana = sales.loc[(sales["State"] == "Telangana")].count()
punjab = sales.loc[(sales["State"] == "Punjab")].count()

l = ['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
       'Gujarat', 'Himachal Pradesh', 'Delhi', 'Madhya Pradesh',
       'Jharkhand', 'Kerala', 'Haryana', 'Bihar', 'Rajasthan',
       'Uttarakhand', 'Telangana', 'Punjab']
#mylist = [maharashtra["state"] , AP["State"] , UP["State"] , karnataka["state"] , gujarat["state"] , himachal_Pradesh["state"] , delhi["state"] , MP["State"] , jharkhand["state"], kerala["state"] , haryana["state"] , bihar["state"] ,rajasthan["state"] , uttarakhand["State"], telangana["state"] , punjab["state"] ,]
counts = [maharashtra["State"], AP["State"], UP["State"], karnataka["State"],
          gujarat["State"], himachal_Pradesh["State"], delhi["State"],
          MP["State"], jharkhand["State"], kerala["State"], haryana["State"],
          bihar["State"], rajasthan["State"], uttarakhand["State"],
          telangana["State"], punjab["State"]]

plt.pie(counts , labels = l  , autopct= '%1.2f%%')
plt.show()

# %% [markdown]
# By the pie chart above we can analise that the there is a few of citys which has 50% of sales . UP , maharashtra , karnataka, andhra pradesh and delhi have the most slaes .

# %%
sales["Zone"].unique()
# Out:
# array(['Western', 'Southern', 'Central', 'Northern', 'Eastern'],
#       dtype=object)

# %%
plt.figure(figsize = (8 , 4))
plt.title("Most sales in Zone")
zone = sns.countplot(data =  sales , x = "Zone" )
zone.bar_label(zone.containers[0])
#zone.bar_label(zone.containers[1])
plt.show()

# %%
plt.figure(figsize = (15 , 6))
plt.title("Most sales in Zone")
zone = sns.countplot(data =  sales , x = "Zone"  , hue = "State") 
zone.bar_label(zone.containers[0])
zone.bar_label(zone.containers[1])
zone.bar_label(zone.containers[2])
zone.bar_label(zone.containers[3])
zone.bar_label(zone.containers[4])
zone.bar_label(zone.containers[5])
zone.bar_label(zone.containers[6])
zone.bar_label(zone.containers[7])
plt.show()

# %% [markdown]
# The plot above have the zone , In which two of zone has expoential slaes central and southern zone .Each zone consist of main city in which sales were most, like central zone have UP and Delhi and southern zone have karnataka and Andhra pradesh and western zone has maharashtra .

# %%
sales["Occupation"].unique()
# Out:
# array(['Healthcare', 'Govt', 'Automobile', 'Construction',
#        'Food Processing', 'Lawyer', 'IT Sector', 'Media', 'Banking',
#        'Retail', 'Hospitality', 'Aviation', 'Agriculture', 'Textile',
#        'Chemical'], dtype=object)

# %%
plt.figure(figsize=(20 , 5))
occ = sns.countplot(data= sales , x = "Occupation" , color = "orange" , palette= 'hls')
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_8688\2448987092.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   occ = sns.countplot(data= sales , x = "Occupation" , color = "orange" , palette= 'hls')

# %%
a = sales.loc[(sales["Occupation"] == "Healthcare")].count()
b = sales.loc[(sales["Occupation"] == "Govt")].count()
c = sales.loc[(sales["Occupation"] == "Automobile")].count()
d = sales.loc[(sales["Occupation"] == "Construction")].count()
e = sales.loc[(sales["Occupation"] == "Food Processing")].count()
f = sales.loc[(sales["Occupation"] == "Lawyer")].count()
g = sales.loc[(sales["Occupation"] == "IT Sector")].count()
h = sales.loc[(sales["Occupation"] == "Media")].count()
i = sales.loc[(sales["Occupation"] == "Banking")].count()
j = sales.loc[(sales["Occupation"] == "Retail")].count()
k = sales.loc[(sales["Occupation"] == "Hospitality")].count()
l_occ = sales.loc[(sales["Occupation"] == "Aviation")].count()
m = sales.loc[(sales["Occupation"] == "Agriculture")].count()
n = sales.loc[(sales["Occupation"] == "Textile")].count()
o = sales.loc[(sales["Occupation"] == "Chemical")].count()

occupation_labels = ['Healthcare', 'Govt', 'Automobile', 'Construction',
                     'Food Processing', 'Lawyer', 'IT Sector', 'Media',
                     'Banking', 'Retail', 'Hospitality', 'Aviation',
                     'Agriculture', 'Textile', 'Chemical']

occupation_counts = [a["Occupation"], b["Occupation"], c["Occupation"], d["Occupation"], e["Occupation"], f["Occupation"],
                     g["Occupation"], h["Occupation"], i["Occupation"], j["Occupation"], k["Occupation"], l_occ["Occupation"],
                     m["Occupation"], n["Occupation"], o["Occupation"]]

# Plotting the pie chart
plt.figure(figsize=(10, 7))
plt.pie(occupation_counts, labels=occupation_labels, autopct='%1.1f%%', startangle=140)
plt.title("Distribution of Occupation")
plt.show()

# %%
plt.figure(figsize=(20 , 5))
plt.title("Occupation")
oc = sns.countplot(data  =sales , x = "Occupation" , hue = "Marital Status")
oc.bar_label(oc.containers[0])
oc.bar_label(oc.containers[1])
plt.show()

# %% [markdown]
# The occupation has a vaital impact in the sales as the add of IT sector , healthcare , aviation and banking is equal to 67% of the total sales . The only men have a trand in IT sector , and other have a large population of females.

# %%
sales["Orders"].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
plt.figure(figsize=(26,6))
plt.title("Orders fequancy from each state")
ox = sns.countplot(data = sales , x = "Orders" , hue = "State" , color = 'blue' , palette= 'hls')
ox.bar_label(ox.containers[0])
ox.bar_label(ox.containers[1])
ox.bar_label(ox.containers[2])
ox.bar_label(ox.containers[3])
ox.bar_label(ox.containers[5])
ox.bar_label(ox.containers[6])
ox.bar_label(ox.containers[7])
ox.bar_label(ox.containers[8])
ox.bar_label(ox.containers[9])
plt.show()

# %%
plt.figure(figsize=(8 , 4))
p = sns.countplot(data = sales , x = "Orders" )
p.bar_label(p.containers[0])
plt.show()

# %% [markdown]
# Order is negligible it have very variance and disperion .

# %%
sales["Amount"].unique
# Out:
# <bound method Series.unique of 0        23952.0
# 1        23934.0
# 2        23924.0
# 3        23912.0
# 4        23877.0
#           ...
# 11246      370.0
# 11247      367.0
# 11248      213.0
# 11249      206.0
# 11250      188.0
# Name: Amount, Length: 11251, dtype: float64>

# %%
sales.head(4)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
#
#             State      Zone    Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western    Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern          Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central    Automobile             Auto       3  23924.0
# 3       Karnataka  Southern  Construction             Auto       2  23912.0

# %%
tm = sales.groupby(sales["Gender"]).agg({"Age" : 'mean', "Orders" : 'mean' , "Amount" : 'mean'})
tm
# Out:
#               Age    Orders       Amount
# Gender
# F       35.336394  2.495282  9491.299340
# M       35.616310  2.475506  9366.972703

# %%
plt.figure(figsize=(5,4))
sns.heatmap(tm , annot= True)
plt.show()

# %% [markdown]
# <h3> So after all the exponential and chart analysis , I have come to the conclusion that there is a higer probability that the unmarried female age reange form 26-35 form up , maharashtra and karnataka who is working in the IT sector , aviation and healthcare and living in the central and southern zones has a high chance of buying  food , Electronics & Gadgets and Clothing & Apparel from the store in the diwali season </h3>
