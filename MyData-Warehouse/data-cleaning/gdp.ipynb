# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
path = "C:\\Users\\mayan\\Downloads\\gapminder_data_graphs.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
#
#    services
# 0      24.4
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6

# %%
df.isnull().sum()
# Out:
# country          0
# continent        0
# year             0
# life_exp         0
# hdi_index      112
# co2_consump      4
# gdp             42
# services         0
# dtype: int64

# %%
sns.heatmap(data = df.isnull(), color = "red" , cbar = False , cmap = "viridis")
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3675 entries, 0 to 3674
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      3675 non-null   object
#  1   continent    3675 non-null   object
#  2   year         3675 non-null   int64
#  3   life_exp     3675 non-null   float64
#  4   hdi_index    3563 non-null   float64
#  5   co2_consump  3671 non-null   float64
#  6   gdp          3633 non-null   float64
#  7   services     3675 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 229.8+ KB

# %%
pd.set_option('display.max_rows', None)

# %%
x  = df.groupby("continent")["country"].value_counts().head(10)
print(x)
# Out:
# continent  country
# Africa     Algeria                     21
#            Angola                      21
#            Benin                       21
#            Botswana                    21
#            Burkina Faso                21
#            Burundi                     21
#            Cameroon                    21
#            Cape Verde                  21
#            Central African Republic    21
#            Chad                        21
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
#
#    services
# 0      24.4
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6

# %%
df.corr(numeric_only= True)
# Out:
#                  year  life_exp  hdi_index  co2_consump       gdp  services
# year         1.000000  0.213317   0.180383    -0.002243  0.057252  0.158690
# life_exp     0.213317  1.000000   0.889623     0.422831  0.585449  0.738371
# hdi_index    0.180383  0.889623   1.000000     0.573901  0.701485  0.832912
# co2_consump -0.002243  0.422831   0.573901     1.000000  0.657385  0.488856
# gdp          0.057252  0.585449   0.701485     0.657385  1.000000  0.649256
# services     0.158690  0.738371   0.832912     0.488856  0.649256  1.000000

# %%
df.describe()
# Out:
#               year     life_exp    hdi_index  co2_consump            gdp  \
# count  3675.000000  3675.000000  3563.000000  3671.000000    3633.000000
# mean   2008.000000    69.849306     0.674864     4.712731   11966.053675
# std       6.056125     8.886563     0.164834     6.567435   17105.787953
# min    1998.000000    32.500000     0.255000     0.015900     238.000000
# 25%    2003.000000    63.900000     0.537500     0.560500    1470.000000
# 50%    2008.000000    71.700000     0.699000     2.250000    4280.000000
# 75%    2013.000000    76.400000     0.805000     6.615000   13600.000000
# max    2018.000000    84.800000     0.956000    67.100000  105000.000000
#
#           services
# count  3675.000000
# mean     51.248705
# std      18.312501
# min       5.590000
# 25%      37.600000
# 50%      52.900000
# 75%      65.700000
# max      88.500000

# %%
plt.bar(data = df ,x ="continent"  , height="year" )
# Out:
# <BarContainer object of 3675 artists>

# %%
sns.boxplot(data = df, x= "continent" , y = "life_exp")
# Out:
# <Axes: xlabel='continent', ylabel='life_exp'>

# %%
df_2002 = df[df["year"] == 2002]
sns.barplot(data=df_2002, x="continent", y="life_exp")
# Out:
# <Axes: xlabel='continent', ylabel='life_exp'>

# %%
sns.barplot(data = df , x = "continent" , y = "life_exp")
# Out:
# <Axes: xlabel='continent', ylabel='life_exp'>

# %%
sns.barplot(data = df , x  = "continent", y = "gdp")
# Out:
# <Axes: xlabel='continent', ylabel='gdp'>

# %%
df_asia = df[df["continent"] == "Asia"]

# %%
plt.Figure(figsize = (150,4))
plt.xticks(rotation=67) 
sns.barplot(data = df_asia , y = "country", x = "gdp" )
plt.show()
